# %% [markdown]
# ## 豆瓣电影 TOP250 电影数据

# %% [markdown]
# 获取电影网页代码, 利用 for 循环实现翻页

# %%
import requests
from bs4 import BeautifulSoup

# %%
def get_movies():
    headers = {'user-agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.82 Safari/537.36', 'Host': 'movie.douban.com'}
    movie_list = []
    
    for i in range(0, 10):
        link = 'http://movie.douban.com/top250?start=' + str(i*25)
        r = requests.get(link, headers=headers, timeout=10)  
        print(str(i+1), "页响应状态码:", r.status_code)
        # print(r.text)
        
        soup = BeautifulSoup(r.text, 'html.parser')
        div_list = soup.find_all('div', class_='hd')
        for each in div_list:
            movie = each.a.span.text.strip()
            movie_list.append(movie)
    return movie_list
               
movies = get_movies()
print(movies)
# Out:
# 1 页响应状态码: 200
# 2 页响应状态码: 200
# 3 页响应状态码: 200
# 4 页响应状态码: 200
# 5 页响应状态码: 200
# 6 页响应状态码: 200
# 7 页响应状态码: 200
# 8 页响应状态码: 200
# 9 页响应状态码: 200
# 10 页响应状态码: 200
# ['肖申克的救赎', '霸王别姬', '阿甘正传', '这个杀手不太冷', '泰坦尼克号', '美丽人生', '千与千寻', '辛德勒的名单', '盗梦空间', '忠犬八公的故事', '海上钢琴师', '星际穿越', '楚门的世界', '三傻大闹宝莱坞', '机器人总动员', '放牛班的春天', '大话西游之大圣娶亲', '熔炉', '疯狂动物城', '无间道', '龙猫', '教父', '当幸福来敲门', '怦然心动', '触不可及', '控方证人', '蝙蝠侠：黑暗骑士', '活着', '末代皇帝', '寻梦环游记', '乱世佳人', '何以为家', '指环王3：王者无敌', '摔跤吧！爸爸', '飞屋环游记', '少年派的奇幻漂流', '十二怒汉', '素媛', '鬼子来了', '哈利·波特与魔法石', '哈尔的移动城堡', '天空之城', '大话西游之月光宝盒', '天堂电影院', '罗马假日', '闻香识女人', '我不是药神', '辩护人', '搏击俱乐部', '教父2', '大闹天宫', '狮子王', '死亡诗社', '指环王2：双塔奇兵', '猫鼠游戏', '窃听风暴', '钢琴家', '指环王1：魔戒再现', '黑客帝国', '美丽心灵', '饮食男女', '两杆大烟枪', '飞越疯人院', '让子弹飞', '本杰明·巴顿奇事', '绿皮书', '看不见的客人', '西西里的美丽传说', '拯救大兵瑞恩', '海蒂和爷爷', '小鞋子', '穿条纹睡衣的男孩', '情书', '海豚湾', '音乐之声', '美国往事', '致命魔术', '低俗小说', '沉默的羔羊', '七宗罪', '蝴蝶效应', '禁闭岛', '心灵捕手', '春光乍泄', '布达佩斯大饭店', '被嫌弃的松子的一生', '摩登时代', '阿凡达', '剪刀手爱德华', '勇敢的心', '喜剧之王', '哈利·波特与死亡圣器(下)', '致命ID', '加勒比海盗', '天使爱美丽', '杀人回忆', '断背山', '狩猎', '请以你的名字呼唤我', '幽灵公主', '7号房的礼物', '阳光灿烂的日子', '小森林 夏秋篇', '第六感', '重庆森林', '红辣椒', '入殓师', '小森林 冬春篇', '消失的爱人', '爱在黎明破晓前', '一一', '唐伯虎点秋香', '侧耳倾听', '蝙蝠侠：黑暗骑士崛起', '超脱', '倩女幽魂', '玛丽和马克思', '无人知晓', '甜蜜蜜', '超能陆战队', '萤火之森', '告白', '大鱼', '阳光姐妹淘', '驯龙高手', '借东西的小人阿莉埃蒂', '菊次郎的夏天', '射雕英雄传之东成西就', '幸福终点站', '爱在日落黄昏时', '恐怖直播', '完美的世界', '功夫', '人生果实', '神偷奶爸', '怪兽电力公司', '玩具总动员3', '天书奇谭', '傲慢与偏见', '血战钢锯岭', '教父3', '时空恋旅人', '哈利·波特与阿兹卡班的囚徒', '风之谷', '釜山行', '电锯惊魂', '哪吒闹海', '被解救的姜戈', '上帝之城', '七武士', '喜宴', '英雄本色', '我是山姆', '谍影重重3', '岁月神偷', '头号玩家', '哈利·波特与密室', '一个叫欧维的男人决定去死', '纵横四海', '疯狂原始人', '三块广告牌', '心迷宫', '达拉斯买家俱乐部', '卢旺达饭店', '你的名字。', '记忆碎片', '花样年华', '萤火虫之墓', '荒蛮故事', '贫民窟的百万富翁', '真爱至上', '东邪西毒', '爆裂鼓手', '黑客帝国3：矩阵革命', '模仿游戏', '忠犬八公物语', '未麻的部屋', '黑天鹅', '头脑特工队', '新世界', '海街日记', '你看起来好像很好吃', '无敌破坏王', '雨人', '冰川时代', '惊魂记', '恋恋笔记本', '二十二', '小偷家族', '恐怖游轮', '海边的曼彻斯特', '房间', '奇迹男孩', '绿里奇迹', '魔女宅急便', '疯狂的石头', '雨中曲', '虎口脱险', '爱在午夜降临前', '人工智能', '罗生门', '终结者2：审判日', '初恋这件小事', '可可西里', '2001太空漫游', '魂断蓝桥', '海洋', '城市之光', '牯岭街少年杀人事件', '燃情岁月', '色，戒', '穿越时空的少女', '哈利·波特与火焰杯', '新龙门客栈', '青蛇', '源代码', '无耻混蛋', '九品芝麻官', '遗愿清单', '完美陌生人', '阿飞正传', '大佛普拉斯', '血钻', '谍影重重2', '地球上的星星', '香水', '疯狂的麦克斯4：狂暴之路', '步履不停', '战争之王', '谍影重重', '彗星来的那一夜', '波西米亚狂想曲', '猜火车', '朗读者', '浪潮', '小萝莉的猴神大叔', '再次出发之纽约遇见你', '东京物语', '驴得水', '聚焦', '追随', '千钧一发', '我爱你', '一次别离', '黑鹰坠落', '黑客帝国2：重装上阵', '网络谜踪', '发条橙', '四个春天', 'E.T. 外星人']
